# %% [markdown]
# ## Análise Descritiva e Preditiva dos dados relativos ao Sistema de Operações do Crédito Rural e do Proagro (Sicor)

# %% [markdown]
# ###  ADENILSON SILVA

# %% [markdown]
# ## EXTRAÇÃO, TRANSFORMAÇÃO E CARRAGAMENTO DE DADOS

# %% [markdown]
# ###  1 - Importando bibliotecas e criando funções

# %%
import pandas as pd  # Manipulação de dados tabulares (DataFrame)
import numpy as np  # Operações com arrays e funções matemáticas
import matplotlib.pyplot as plt  # Criação de gráficos
import seaborn as sns
import basedosdados as bd  # Acesso a dados públicos da Base dos Dados
from datetime import datetime  # Manipulação de datas e horas

# %%
def categoria_tempo_empresa(idade):
    if idade <= 5:
        return 'Nova'
    elif idade <= 15:
        return 'Em crescimento'
    elif idade <= 30:
        return 'Consolidada'
    else:
        return 'Tradicional'

# %% [markdown]
# ### 2 - Leitura dos dados

# %%
billing_id = "projeto"

# %%
# %%time

query = """
 SELECT
    empreendimento.id_empreendimento as id_empreendimento,
    empreendimento.data_inicio as data_inicio_empreendimento,
    empreendimento.data_fim as data_fim_emprendimento,
    empreendimento.finalidade as finalidade,
    empreendimento.atividade as atividade,
    empreendimento.modalidade as modalidade,
    empreendimento.produto as produto,
    empreendimento.variedade as variedade,
    empreendimento.cesta_safra as cesta_safra,
    empreendimento.zoneamento as zoneamento,
    empreendimento.consorcio as consorcio
FROM `basedosdados.br_bcb_sicor.empreendimento` AS empreendimento 
"""

#Salvando dados brutos oriundos do Google Cloud
data = bd.read_sql(query = query, billing_project_id = billing_id) 
data.to_parquet('dados/dados_brutos/dados_brutos_empreendimento.parquet')
df_empreendimento = pd.read_parquet('dados/dados_brutos/dados_brutos_empreendimento.parquet')
df_empreendimento.head()
# Out:
# Downloading: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████|
# Wall time: 2 s
#   id_empreendimento data_inicio_empreendimento data_fim_emprendimento  \
# 0    22507460333408                 2018-08-29                    NaT
# 1    12016565000053                 2021-02-03                    NaT
# 2    12016560000043                 2017-05-15                    NaT
# 3    12014580000013                 2017-03-20             2020-04-03
# 4    12014320000043                 2017-03-20                    NaT
#
#   finalidade    atividade modalidade                      produto  \
# 0    custeio  pecuario(a)      pesca  armacao para barco de pesca
# 1    custeio     agricola    lavoura                       sapoti
# 2    custeio     agricola    lavoura                        salsa
# 3    custeio     agricola    lavoura                        linho
# 4    custeio     agricola    lavoura              lichia (lechia)
#
#               variedade                    cesta_safra zoneamento  \
# 0  manutencao/aquisicao  ano civil / ano de exploracao       None
# 1         nao se aplica                      irrigadas       None
# 2         nao se aplica    fruticultura / olericultura       None
# 3         nao se aplica      safra de verao (1ª safra)       None
# 4         nao se aplica    fruticultura / olericultura       None
#
#          consorcio
# 0   valor invalido
# 1  nao consorciado
# 2  nao consorciado
# 3  nao consorciado
# 4  nao consorciado

# %%
# %%time

query = """
 SELECT id_empreendimento as id_empreendimento, 
 ano as ano, 
 taxa_juro as taxa_juro,
 sigla_uf as sigla_uf
FROM `basedosdados.br_bcb_sicor.microdados_operacao`
 WHERE id_empreendimento IS NOT NULL
"""

#Salvando dados brutos oriundos do Google Cloud
data = bd.read_sql(query = query, billing_project_id = billing_id) 
data.to_parquet('dados/dados_brutos/dados_brutos_operacao.parquet')
df_operacao = pd.read_parquet('dados/dados_brutos/dados_brutos_operacao.parquet')
df_operacao.head()
# Out:
# Downloading: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████|
# Wall time: 21min 50s
#   id_empreendimento   ano  taxa_juro sigla_uf
# 0    23271300191002  2016        0.5       AL
# 1    23271300191002  2016        0.5       AL
# 2    23271300193002  2016        5.5       AL
# 3    23271300193002  2016        5.5       BA
# 4    23271300193002  2016        0.5       AL

# %%
# Junção dos dataframes
df = pd.merge(df_empreendimento, df_operacao, how='inner', on='id_empreendimento')
df.head()
# Out:
#   id_empreendimento data_inicio_empreendimento data_fim_emprendimento  \
# 0    22507460333408                 2018-08-29                    NaT
# 1    22507460333408                 2018-08-29                    NaT
# 2    22507460333408                 2018-08-29                    NaT
# 3    22507460333408                 2018-08-29                    NaT
# 4    22507460333408                 2018-08-29                    NaT
#
#   finalidade    atividade modalidade                      produto  \
# 0    custeio  pecuario(a)      pesca  armacao para barco de pesca
# 1    custeio  pecuario(a)      pesca  armacao para barco de pesca
# 2    custeio  pecuario(a)      pesca  armacao para barco de pesca
# 3    custeio  pecuario(a)      pesca  armacao para barco de pesca
# 4    custeio  pecuario(a)      pesca  armacao para barco de pesca
#
#               variedade                    cesta_safra zoneamento  \
# 0  manutencao/aquisicao  ano civil / ano de exploracao       None
# 1  manutencao/aquisicao  ano civil / ano de exploracao       None
# 2  manutencao/aquisicao  ano civil / ano de exploracao       None
# 3  manutencao/aquisicao  ano civil / ano de exploracao       None
# 4  manutencao/aquisicao  ano civil / ano de exploracao       None
#
#         consorcio   ano  taxa_juro sigla_uf
# 0  valor invalido  2020       6.00       SC
# 1  valor invalido  2023       5.00       SP
# 2  valor invalido  2023       5.00       SC
# 3  valor invalido  2022       4.50       ES
# 4  valor invalido  2021       5.75       MA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21497976 entries, 0 to 21497975
# Data columns (total 14 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   id_empreendimento           object
#  1   data_inicio_empreendimento  dbdate
#  2   data_fim_emprendimento      dbdate
#  3   finalidade                  object
#  4   atividade                   object
#  5   modalidade                  object
#  6   produto                     object
#  7   variedade                   object
#  8   cesta_safra                 object
#  9   zoneamento                  object
#  10  consorcio                   object
#  11  ano                         Int64
#  12  taxa_juro                   float64
#  13  sigla_uf                    object
# dtypes: Int64(1), dbdate(2), float64(1), object(10)
# memory usage: 2.3+ GB

# %%
df.describe(include='all')
# Out:
#        id_empreendimento data_inicio_empreendimento data_fim_emprendimento  \
# count           21497976                   21497976                7167034
# unique              2327                        396                    104
# top       12016720000011                 1984-01-01             2020-02-29
# freq             1564283                   12068783                2072751
# mean                 NaN                        NaN                    NaN
# std                  NaN                        NaN                    NaN
# min                  NaN                        NaN                    NaN
# 25%                  NaN                        NaN                    NaN
# 50%                  NaN                        NaN                    NaN
# 75%                  NaN                        NaN                    NaN
# max                  NaN                        NaN                    NaN
#
#           finalidade    atividade modalidade   produto      variedade  \
# count       21490576     21497976   21497976  21497976       21497976
# unique             3            2         51       375            321
# top     investimento  pecuario(a)    lavoura   bovinos  nao se aplica
# freq        11851916     11662546    6002941   5985014        8191510
# mean             NaN          NaN        NaN       NaN            NaN
# std              NaN          NaN        NaN       NaN            NaN
# min              NaN          NaN        NaN       NaN            NaN
# 25%              NaN          NaN        NaN       NaN            NaN
# 50%              NaN          NaN        NaN       NaN            NaN
# 75%              NaN          NaN        NaN       NaN            NaN
# max              NaN          NaN        NaN       NaN            NaN
#
#                           cesta_safra   zoneamento        consorcio  \
# count                        21497976     19254698         21404452
# unique                            125           90               53
# top     ano civil / ano de exploracao  nao zoneado  nao consorciado
# freq                         10443000      9724233         14351582
# mean                              NaN          NaN              NaN
# std                               NaN          NaN              NaN
# min                               NaN          NaN              NaN
# 25%                               NaN          NaN              NaN
# 50%                               NaN          NaN              NaN
# 75%                               NaN          NaN              NaN
# max                               NaN          NaN              NaN
#
#                 ano     taxa_juro  sigla_uf
# count    21497976.0  2.149798e+07  21497976
# unique         <NA>           NaN        27
# top            <NA>           NaN        RS
# freq           <NA>           NaN   3473579
# mean    2017.283651  3.619639e+00       NaN
# std        3.026584  3.478915e+00       NaN
# min          2013.0 -2.520000e+00       NaN
# 25%          2014.0  5.000000e-01       NaN
# 50%          2017.0  3.000000e+00       NaN
# 75%          2020.0  5.500000e+00       NaN
# max          2023.0  1.000000e+02       NaN

# %% [markdown]
# ### 3 - Tratando os dados

# %%
# Convertendo o tipo da coluna datas e criando a coluna 'ano_criacao_empresa'
df['data_inicio_empreendimento'] = pd.to_datetime(df['data_inicio_empreendimento']) 
df['data_fim_emprendimento'] = pd.to_datetime(df['data_fim_emprendimento'])
df['ano_criacao_empresa'] = df['data_inicio_empreendimento'].dt.year

# %%
# Criando a coluna 'categoria_empresa' que define se a empresa é Nova, Em crescimento, Consolidada ou Tradicional
ano_atual = datetime.now().year
df['categoria_empresa'] = (ano_atual - df['ano_criacao_empresa']).apply(categoria_tempo_empresa)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21497976 entries, 0 to 21497975
# Data columns (total 16 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   id_empreendimento           object
#  1   data_inicio_empreendimento  datetime64[ns]
#  2   data_fim_emprendimento      datetime64[ns]
#  3   finalidade                  object
#  4   atividade                   object
#  5   modalidade                  object
#  6   produto                     object
#  7   variedade                   object
#  8   cesta_safra                 object
#  9   zoneamento                  object
#  10  consorcio                   object
#  11  ano                         Int64
#  12  taxa_juro                   float64
#  13  sigla_uf                    object
#  14  ano_criacao_empresa         int32
#  15  categoria_empresa           object
# dtypes: Int64(1), datetime64[ns](2), float64(1), int32(1), object(11)
# memory usage: 2.5+ GB

# %%
df.isna().sum()
# Out:
# id_empreendimento                    0
# data_inicio_empreendimento           0
# data_fim_emprendimento        14330942
# finalidade                        7400
# atividade                            0
# modalidade                           0
# produto                              0
# variedade                            0
# cesta_safra                          0
# zoneamento                     2243278
# consorcio                        93524
# ano                                  0
# taxa_juro                            0
# sigla_uf                             0
# ano_criacao_empresa                  0
# categoria_empresa                    0
# dtype: int64

# %%
df['finalidade'] = df['finalidade'].fillna('Outros')

# %%
df.isna().sum()
# Out:
# id_empreendimento                    0
# data_inicio_empreendimento           0
# data_fim_emprendimento        14330942
# finalidade                           0
# atividade                            0
# modalidade                           0
# produto                              0
# variedade                            0
# cesta_safra                          0
# zoneamento                     2243278
# consorcio                        93524
# ano                                  0
# taxa_juro                            0
# sigla_uf                             0
# ano_criacao_empresa                  0
# categoria_empresa                    0
# dtype: int64

# %%
# Removendo colunas desnecessárias
colunas = ['id_empreendimento',
            'zoneamento']
df = df.drop(columns=colunas)
df.head(5)
# Out:
#   data_inicio_empreendimento data_fim_emprendimento finalidade    atividade  \
# 0                 2018-08-29                    NaT    custeio  pecuario(a)
# 1                 2018-08-29                    NaT    custeio  pecuario(a)
# 2                 2018-08-29                    NaT    custeio  pecuario(a)
# 3                 2018-08-29                    NaT    custeio  pecuario(a)
# 4                 2018-08-29                    NaT    custeio  pecuario(a)
#
#   modalidade                      produto             variedade  \
# 0      pesca  armacao para barco de pesca  manutencao/aquisicao
# 1      pesca  armacao para barco de pesca  manutencao/aquisicao
# 2      pesca  armacao para barco de pesca  manutencao/aquisicao
# 3      pesca  armacao para barco de pesca  manutencao/aquisicao
# 4      pesca  armacao para barco de pesca  manutencao/aquisicao
#
#                      cesta_safra       consorcio   ano  taxa_juro sigla_uf  \
# 0  ano civil / ano de exploracao  valor invalido  2020       6.00       SC
# 1  ano civil / ano de exploracao  valor invalido  2023       5.00       SP
# 2  ano civil / ano de exploracao  valor invalido  2023       5.00       SC
# 3  ano civil / ano de exploracao  valor invalido  2022       4.50       ES
# 4  ano civil / ano de exploracao  valor invalido  2021       5.75       MA
#
#    ano_criacao_empresa categoria_empresa
# 0                 2018    Em crescimento
# 1                 2018    Em crescimento
# 2                 2018    Em crescimento
# 3                 2018    Em crescimento
# 4                 2018    Em crescimento

# %% [markdown]
# ### 4 - Salvando os dados tratados

# %%
df.to_parquet('dados/dados_tratados/dados_tratados.parquet')
df.to_csv('dados/dados_tratados/dados_tratados.csv', index=False)

# %% [markdown]
# ### Dados sobre versão

# %%
import sys
import pandas as pd
import numpy as np
import matplotlib as mat
import basedosdados as bd
print("Python:", sys.version)
print("pandas:", pd.__version__)
print("numpy:", np.__version__)
print("matplotlib:", mat.__version__)
print("basedosdados:", bd.__version__)
# Out:
# Python: 3.9.7 (default, Sep 16 2021, 16:59:28) [MSC v.1916 64 bit (AMD64)]
# pandas: 2.2.3
# numpy: 1.23.5
# matplotlib: 3.9.4
# basedosdados: 2.0.2
